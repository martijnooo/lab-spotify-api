# %% [markdown]
# # Installing Spotipy

# %%
##!conda install -c conda-forge spotipy

# %% [markdown]
# ## Loading credentials from the config file

# %% [markdown]
# #### Make sure that you have stored your spotify client_id and client_secret in a separate config.py file
# #### Once that's done, we import it

# %%
from dotenv import load_dotenv
import os

load_dotenv()
SPOTIPY_CLIENT_SECRET = os.getenv("spotify_secret_key")
SPOTIPY_CLIENT_ID = os.getenv("spotify_client_id")

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pprint

#Initialize SpotiPy with user credentials

# %%
auth_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# # Understanding the json

# %%
playlists = sp.user_playlists('spotify', limit=10)
print(playlists)
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print(f"{i + 1 + playlists['offset']:4d} {playlist['uri']} {playlist['name']}")
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
# Out:
# {'href': 'https://api.spotify.com/v1/users/spotify/playlists?offset=0&limit=10', 'limit': 10, 'next': 'https://api.spotify.com/v1/users/spotify/playlists?offset=10&limit=10', 'offset': 0, 'previous': None, 'total': 348, 'items': [{'collaborative': False, 'description': 'All songs about drinking, cheating, heartaches and everything else going on in a classic honky tonk.', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/0NfjMqrzcGKVsbYZmhf4Md'}, 'href': 'https://api.spotify.com/v1/playlists/0NfjMqrzcGKVsbYZmhf4Md', 'id': '0NfjMqrzcGKVsbYZmhf4Md', 'images': [{'height': None, 'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da8430ec0eff4844b5161b5075b0', 'width': None}], 'name': 'Classic Honky Tonk', 'owner': {'display_name': 'Spotify', 'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'}, 'href': 'https://api.spotify.com/v1/users/spotify', 'id': 'spotify', 'type': 'user', 'uri': 'spotify:user:spotify'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAAC/9fnrEKWUIXFE/48FUgTppvFjnb', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/0NfjMqrzcGKVsbYZmhf4Md/tracks', 'total': 50}, 'type': 'playlist', 'uri': 'spotify:playlist:0NfjMqrzcGKVsbYZmhf4Md'}, {'collaborative': False, 'description': 'Go behind the scenes of the <a href="http://www.twobytwomusic.com">Two By Two</a> book soundtrack curated by <a href="spotify:user:nicholassparksofficial">Nicholas Sparks</a> and featuring songs from <a href="spotify:artist:410MPX0LjYx4PFgIJsBbPT">JD Eicher</a>. Then, linger a while with soundtrack selections from your favorite Nicholas Sparks films.', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/1scnlLVq91NGtsA9sh0hfw'}, 'href': 'https://api.spotify.com/v1/playlists/1scnlLVq91NGtsA9sh0hfw', 'id': '1scnlLVq91NGtsA9sh0hfw', 'images': [{'height': None, 'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84effe6dfc6e869087ba7673e3', 'width': None}], 'name': 'Nicholas Sparks | Songs from the Soundtracks', 'owner': {'display_name': 'Spotify', 'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'}, 'href': 'https://api.spotify.com/v1/users/spotify', 'id': 'spotify', 'type': 'user', 'uri': 'spotify:user:spotify'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAAVdVsQXTQ/8fXUffk8Wu+wRRxZnAc', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/1scnlLVq91NGtsA9sh0hfw/tracks', 'total': 53}, 'type': 'playlist', 'uri': 'spotify:playlist:1scnlLVq91NGtsA9sh0hfw'}, {'collaborative': False, 'description': 'Those were the days, this was the music...', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/2NFOUmp2wyR5CrXtKDkUkB'}, 'href': 'https://api.spotify.com/v1/playlists/2NFOUmp2wyR5CrXtKDkUkB', 'id': '2NFOUmp2wyR5CrXtKDkUkB', 'images': [{'height': None, 'url': 'https://image-cdn-fa.spotifycdn.com/image/ab67706c0000da8404d197c8af266f42c9de09a5', 'width': None}], 'name': '1960s Nostalgia', 'owner': {'display_name': 'Spotify', 'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'}, 'href': 'https://api.spotify.com/v1/users/spotify', 'id': 'spotify', 'type': 'user', 'uri': 'spotify:user:spotify'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAANNasNqI3GxP0hHObuYAE7INdl3Zh', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/2NFOUmp2wyR5CrXtKDkUkB/tracks', 'total': 67}, 'type': 'playlist', 'uri': 'spotify:playlist:2NFOUmp2wyR5CrXtKDkUkB'}, {'collaborative': False, 'description': 'From denial and pleading to anger and acceptance, this genre-blending playlist will carry you through each stage of your breakup blues.', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/1o2bTwofazfzElA5mXGf2t'}, 'href': 'https://api.spotify.com/v1/playlists/1o2bTwofazfzElA5mXGf2t', 'id': '1o2bTwofazfzElA5mXGf2t', 'images': [{'height': None, 'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84db632a978704a829d52eb448', 'width': None}], 'name': 'Breakup Blues', 'owner': {'display_name': 'Spotify', ...
#    1 spotify:playlist:0NfjMqrzcGKVsbYZmhf4Md Classic Honky Tonk
#    2 spotify:playlist:1scnlLVq91NGtsA9sh0hfw Nicholas Sparks | Songs from the Soundtracks
#    3 spotify:playlist:2NFOUmp2wyR5CrXtKDkUkB 1960s Nostalgia
#    4 spotify:playlist:1o2bTwofazfzElA5mXGf2t Breakup Blues
#    5 spotify:playlist:6cdV0hVW2suJaMOxzwE46S I Hate My Job.
#    6 spotify:playlist:2uhsnHgI4F2eFyvoMHY0GR Instrumental Rock
#    7 spotify:playlist:2uVP1agvV5rba3MqLQ0pzy Avant Folk
#    8 spotify:playlist:0BbcjurkvWrkWxKKLzcqIP The Perfect Crafternoon
#    9 spotify:playlist:44XJR1i3Vl2B3acOEYwinE Power Ballads
#   10 spotify:playlist:2YeGkAUQhmO8TCjSMbFYWf Energy + Positivity
#   11 spotify:playlist:0op6xwVK9pVhcxozSQPEsJ Namaste
#   12 spotify:playlist:2Ph68VcwRfqRdnrKhY3oPS Rustic Romance Wedding
#   13 spotify:playlist:2VxQy0Q22k1gP542tzaMCN Word of Mouth
#   14 spotify:playlist:0sDO43KAaJUWIYassTKWYf Indie Strings
#   15 spotify:playlist:2B64RN7KJte5x6iXgg02tv Vinyasa Flow
#   16 spotify:playlist:3OUguxmuL5x24sMAw4qPku Acoustic Commute
#   17 spotify:playlist:5v2J2noHVxPWgSrOw6lZsp Summertime Vibes
#   18 spotify:playlist:1W2XJETQjFYdzT4GuhBHmS More Banjo!
#   19 spotify:playlist:43rSnXFDoctqiZxvEqH14P Chill as Folk
#   20 spotify:playlist:1IKDP8o4UvpfLh0SJX2e1b The New Bohemian
#   21 spotify:playlist:44Ht3IACEyKqiLBZupIhIk Sweetgrass
#   22 spotify:playlist:62Tpw0jhT8kxF3KPbGciTk Sweet Winter Songs
#   23 spotify:playlist:0pHFNRP8qkYhal0q0Irp6D Disco Beats
#   24 spotify:playlist:7pD7pMFxcq8agMXqLQCggM Rock & Roots
#   25 spotify:playlist:0XDRWlx2B1C1OXlaLlld8t Interstate Drive Songs
#   26 spotify:playlist:67uEKAhAdvMJvumeC8ZgjB Low Key Revelry
#  252 spotify:playlist:54LbSpjd64NjKPUyYAGkNU Hours of Ours
#  253 spotify:playlist:4p3lupatTubTWpTgCZjgpk Walk a Country Mile
#  254 spotify:playlist:6tLfPD2P9syvBV8rgO2Yq1 Honeysuckle Lazy
#  255 spotify:playlist:3FfBohQXFlgFnYubzrvoq4 On to Something Good
#  256 spotify:playlist:1S4JPQeJxtsN37X8as5EPk Back to the Roots
#  257 spotify:playlist:7CHrwiytyubNpnaZqyyUkb Beer 'n Burgers
#  258 spotify:playlist:4LmOnbOmtMUyQQjo6L9mct Bossa Nova
#  261 spotify:playlist:653U7cDBXXkPZ07Xk8kxL6 King of Pop
#  262 spotify:playlist:7hjaw2oDqkMS2uDk5vmzAu The Jazz Escape
#  263 spotify:playlist:6MtNKlWguIlTJ6Q7WAcDtU Workday - Country
#  264 spotify:playlist:3TurM2x1HaeNEztqBnomV6 Workday - Singer-songwriter
#  265 spotify:playlist:5rqcJUB5ox8BK3L3Ki7gfF Tunigo Live
#  266 spotify:playlist:4lCv0oN3gPxoqvXmA3cDjS Top Picks Toplists
#  267 spotify:playlist:3xGWOQUB6jgHd4PLVQvbfG Top Picks Pop
#  268 spotify:playlist:0q2dbyUyAuUkW3ec6XRwJD Top Picks Decades
#  269 spotify:playlist:45mRKVQrL1pK9tbRp25yro Top Picks Workout
#  270 spotify:playlist:1EQVvrXxgoWdqUHni1LOgm Top Picks Mood
#  271 spotify:playlist:4ruhrP9ntTdDMpjrk22v9u Top Picks Kids
#  272 spotify:playlist:3jh9R9uXIoozPA0uccJt2C Top Picks Classical
#  273 spotify:playlist:5QZZbWjNVjynssxTuO3f0f Top Picks Pop Culture
#  274 spotify:playlist:2WIkzIBRwM9wRD9innJ8b7 Top Picks Party
#  275 spotify:playlist:2b5yd7Ox7vb4OcPOOVYwFZ Top Picks Chill
#  276 spotify:playlist:6spPs4oxQEPSWXyXzqg8CR Top Picks Urban
#  277 spotify:playlist:285xVjuyHG2CusStdc8kCS Top Picks Club
#  278 spotify:playlist:7hx7ugiU2MaeXOjQRVDzdk Top Picks Country
#  279 spotify:playlist:2Mecjd64RGHE4vLDMuX88V Top Picks Events
#  280 spotify:playlist:38ZGEwSsiHoOEOu446h75W Top Picks Groove
#  281 spotify:playlist:5QOzTki17fEWKoUVcvTrI2 Top Picks Rock
#  282 spotify:playlist:4tSzT9BRuf3qRJDbPz4SlS Top Picks Romance
#  283 spotify:playlist:5LrQkRUFFuKWAJCECd2X9y Top Picks Jazz and Blues
#  284 spotify:playlist:4NAi06Izmj4CPqmMuY1RsE Top Picks Travel
#  285 spotify:playlist:4uLnCAHJw65SyFXXmBSuc0 Top Picks holiday
#  286 spotify:playlist:2ZMfoURN2ZwapN17Yb5d1k Undiscovered bands
#  287 spotify:playlist:2EaYMuzaVSdPjJOqg77E2E Women of Sweden
#  288 spotify:playlist:1m6DKwKNM1YLcm3OX6RzJg Kvinnor att ha koll på 2014
#  289 spotify:playlist:1xAmEtLT8c17IisGUa1f4M 38 Great Female Duets
#  290 spotify:playlist:7oTMBMLu6EI4l163C9fkhg Best of Boybands and Girl Groups
#  327 spotify:playlist:0mJut6QO3dUUAOJlBPujT1 Popaganda 2012
#  328 spotify:playlist:6cSO5pHOCQxoEiXYDPa3Uq Metaltown 2012
#  329 spotify:playlist:7b1rMSnmiYfj8nH8spIjxF Urkult 2012
#  330 spotify:playlist:2xxkK8eaOyM6JRhHOheZBZ Sweden Rock Festival 2012
#  331 spotify:playlist:26yS4HN010lrCBBlCbjF2b Hultsfred 2012
#  332 spotify:playlist:5eRHTcvWyEU0MEzNOiR2j1 Putte i parken 2012
#  333 spotify:playlist:4mM7tVGeVv4dOFPTlftofk Getaway Rock 2012
#  334 spotify:playlist:7DcfXNVB5WpzYwCkqBaVDx Peace & Love 2012
#  335 spotify:playlist:33eWAE7F4bBUAjGtJVtCYB Sveriges Nationaldag
#  336 spotify:playlist:3ukqAcaahACMyRzpkwHXew New year's eve by Icona Pop
#  337 spotify:playlist:5zyeLrOc31CPX7uk9xNL7y Swing in the New Year
#  338 spotify:playlist:214Nwj78JwTfjSeQxbGxeX Alternative New Year's Eve
#  339 spotify:playlist:3yUO32lGCEnAfFGORSEsy4 Raw Expression
#  340 spotify:playlist:2k9EArKbf7N3QUmuNJHSo8 Intervju med Seinabo Sey
#  341 spotify:playlist:5sk53m6HgZorO1RDUkaiIZ The official Bråvalla Festival playlist 2017
#  342 spotify:playlist:73boXMJz9iBoXxQVFZ94r5 International Playboy
#  343 spotify:playlist:2y74Ha0ztRUcIYmqITh0D4 National Blood Week
#  344 spotify:playlist:1k9jG0FUp7BcrAF1MZSabO Most Listened To British Dads on Spotify
#  345 spotify:playlist:5ji4GZJpll6twskFvKxiHx dw-c
#  346 spotify:playlist:40VxbK9NqccdUDUpiUXmbp dw_g
#  347 spotify:playlist:0RTz1jFo5BXGPfI8eVf8sj Top Shower Songs
#  348 spotify:playlist:4lgseztVwmKQ8MNETPVIny foodora dinner playlist

# %% [markdown]
# ## Getting the track_id

# %%
search = sp.search('Indie', limit=10)

# Extracting track details from the search results
tracks = search['tracks']['items']

# Creating a DataFrame with relevant information
df_tracks = pd.DataFrame([{
    'Track Name': track['name'],
    'Artist': ', '.join(artist['name'] for artist in track['artists']),
    'Album': track['album']['name'],
    'Track ID': track['id'],
    'Popularity': track['popularity']
} for track in tracks])

display(df_tracks)
# Out:
#                                           Track Name  \
# 0                                              Indie
# 1  WE PRAY (feat. Little Simz, Burna Boy, Elyanna...
# 2                                              Indie
# 3                                              Indie
# 4                                      Friendly Fire
# 5                                              Indie
# 6                                              Indie
# 7                                 Heavy Is the Crown
#
#                                             Artist  \
# 0                             Ost & Kjex, Frøkedal
# 1  Coldplay, Little Simz, Burna Boy, Elyanna, tINI
# 2                                         MoonMoon
# 3                                          Up & Pg
# 4                                      Linkin Park
# 5                                         331Music
# 6                                           AMPISH
# 7                                      Linkin Park
#
#                             Album                Track ID  Popularity
# 0                            Lulu  7rSuqMaEloVncVc8RDdoDX          35
# 1         Indie Artists on Repeat  55fSfHNthQyaT0RQEBQH4D           0
# 2                       Long Poem  6oVdkLtgzrDmeNisp9o4mc          18
# 3  40 Masters of Techno & Minimal  6M2YbJ14Uk2UIMC5s56fUL           0
# 4         Indie Artists on Repeat  1oXHhNYBxpfky1WjnoGZuN           0
# 5   Royalty Free Background Music  3S04lhLcIP2IAgv2ifq2UC          19
# 6                Indie / Glitches  6OhY6laZEBXfn0oa78nhAX          26
# 7         Indie Artists on Repeat  1hy74cUr3DwwvooLeFcFvt           1

# %% [markdown]
# ## Embedded track player

# %%
from IPython.display import HTML

HTML("""
<iframe style="border-radius:12px" src="https://open.spotify.com/embed/playlist/4lgseztVwmKQ8MNETPVIny?utm_source=generator" width="100%" height="352" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>
""")
# Out:
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/playlist/4lgseztVwmKQ8MNETPVIny?utm_source=generator" width="100%" height="352" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy"></iframe>

# %% [markdown]
# # Getting the Audio features of a song

# %% [markdown]
# ## Building a Data frame of audio features

# %%
scope = "user-library-read"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET, redirect_uri="https://www.linkedin.com/in/martijn-balder/", scope=scope))

# %%
# Extract the track ID from the URL
track_id = "4PTG3Z6ehGkBFwjybzWkR8"

# Fetch the audio features for the track
audio_features = sp.audio_features(tracks=[track_id])
print(audio_features)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=4PTG3Z6ehGkBFwjybzWkR8 with Params: {} returned 403 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Martijn\anaconda3\envs\datasci_env\lib\site-packages\spotipy\client.py:271, in Spotify._internal_call(self, method, url, payload, params)
#     266 response = self._session.request(
#     267     method, url, headers=headers, proxies=self.proxies,
#     268     timeout=self.requests_timeout, **args
#     269 )
# --> 271 response.raise_for_status()
#     272 results = response.json()
#
# File c:\Users\Martijn\anaconda3\envs\datasci_env\lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/audio-features/?ids=4PTG3Z6ehGkBFwjybzWkR8
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[96], line 5
#       2 track_id = "4PTG3Z6ehGkBFwjybzWkR8"
#       4 # Fetch the audio features for the track
# ----> 5 audio_features = sp.audio_features(tracks=[track_id])
#       6 print(audio_features)
#
# File c:\Users\Martijn\anaconda3\envs\datasci_env\lib\site-packages\spotipy\client.py:1737, in Spotify.audio_features(self, tracks)
#    1735 else:
#    1736     tlist = [self._get_id("track", t) for t in tracks]
# -> 1737     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1738 # the response has changed, look for the new style first, and if
#    1739 # its not there, fallback on the old style
#    1740 if "audio_features" in results:
#
# File c:\Users\Martijn\anaconda3\envs\datasci_env\lib\site-packages\spotipy\client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\Martijn\anaconda3\envs\datasci_env\lib\site-packages\spotipy\client.py:293, in Spotify._internal_call(self, method, url, payload, params)
#     286         reason = None
#     288     logger.error(
#     289         'HTTP Error for %s to %s with Params: %s returned %s due to %s',
#     290         method, url, args.get("params"), response.status_code, msg
#     291     )
# --> 293     raise SpotifyException(
#     294         response.status_code,
#     295         -1,
#     296         "%s:\n %s" % (response.url, msg),
#     297         reason=reason,
#     298         headers=response.headers,
#     299     )
#     300 except requests.exceptions.RetryError as retry_error:
#     301     request = retry_error.request
#
# SpotifyException: http status: 403, code:-1 - https://api.spotify.com/v1/audio-features/?ids=4PTG3Z6ehGkBFwjybzWkR8:
#  None, reason: None

# %% [markdown]
# --> Feature disabled

# %% [markdown]
# ## Searching a playlist

# %%
search = sp.search('Code',  type='playlist', limit=10)

# Extracting track details from the search results
playlists = search['playlists']['items']

# Creating a DataFrame with relevant information
df_playlists = pd.DataFrame([{
    'Playlist Name': playlist['name'],
    'Playlist Description': playlist['description'],
    'Link': playlist['external_urls']["spotify"],
} for playlist in playlists if playlist is not None])

display(df_playlists)
# Out:
#                                        Playlist Name  \
# 0                    Code geass openings and endings
# 1                                        18-Code red
# 2  Codename Anastasia 🐊🐇 | To listen while readin...
# 3                                         CODE BARRE
# 4        Hans Zimmer LIVE – The World of Hans Zimmer
# 5  Uzi mit Schalldämpfer sie ist fast so groß wie...
# 6                          sluttiest kpop songs EVER
# 7  CHILL BEATS – lofi jazz hop / lo-fi chillhop /...
#
#                                 Playlist Description  \
# 0  All official openings and endings of code geas...
# 1
# 2
# 3
# 4  His Greatest Hits-Music from legendary Hans Zi...
# 5
# 6     a collection of my fav slut-coded kpop songs 🧌
# 7  ♡ follow for daily updates + share with friend...
#
#                                                 Link
# 0  https://open.spotify.com/playlist/0qLXsS5SM9G0...
# 1  https://open.spotify.com/playlist/5ueX9uBuBsVR...
# 2  https://open.spotify.com/playlist/76ePBisVKcZX...
# 3  https://open.spotify.com/playlist/49F1jRr6cASn...
# 4  https://open.spotify.com/playlist/4TArpT8rNOwa...
# 5  https://open.spotify.com/playlist/1izBBlmUlzpH...
# 6  https://open.spotify.com/playlist/2DJly09ju3Lg...
# 7  https://open.spotify.com/playlist/3G1pIa3dYHK4...

# %% [markdown]
# ## Extracting a song from playlist

# %%
playlist = sp.playlist("3uq1jrrLNf3nbqO9cV4NCK")

# %%
playlist["tracks"]["items"][0]["track"]["name"]
# Out:
# 'Complicated'

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next".
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
playlist = sp.playlist("3uq1jrrLNf3nbqO9cV4NCK")
songs = []
while playlist:
    for i, item in enumerate(playlist['tracks']['items']):
        # print(f"{item['track']['name']}")
        songs.append(item['track']['name'])
    if playlist['tracks']['next']:
        playlist['tracks'] = sp.next(playlist['tracks'])
    else:
        playlist = None

# %% [markdown]
# ## Optional(Extra)

# %% [markdown]
# ## Getting the artists of the playlist

# %%
playlist = sp.playlist("3uq1jrrLNf3nbqO9cV4NCK")
playlist
# Out:
# {'collaborative': False,
#  'description': 'The Official Pamela Reif workout playlist | Get Active | Fitness | Fit mit Beat | Workout at Home | Dance Soundtrack für dein Workout Zuhause | EDM Beats | Work Out Motivation | Cardio Training ohne Gym | Warm Up | Stretch',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/3uq1jrrLNf3nbqO9cV4NCK'},
#  'followers': {'href': None, 'total': 301284},
#  'href': 'https://api.spotify.com/v1/playlists/3uq1jrrLNf3nbqO9cV4NCK?additional_types=track',
#  'id': '3uq1jrrLNf3nbqO9cV4NCK',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000d72c51648b7bcdad68905f838945',
#    'width': None}],
#  'name': 'Pamela Reif Workout Songs - Get Active by Pamela Reif (Official)',
#  'owner': {'display_name': 'Topsify Deutschland',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#   'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#   'id': 'warner.music.central.europe',
#   'type': 'user',
#   'uri': 'spotify:user:warner.music.central.europe'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAALqBKtkEcHJBUvxqHvEwu3veT3Vblq',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/3uq1jrrLNf3nbqO9cV4NCK/tracks?offset=0&limit=100&additional_types=track',
#   'items': [{'added_at': '2025-04-18T07:25:07Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#      'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#      'id': 'warner.music.central.europe',
#      'type': 'user',
#      'uri': 'spotify:user:warner.music.central.europe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'CW',
#       'DM',
#       'FJ',
#       'GE',
#       'GD',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'MH',
#       'FM',
#       'NR',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'KH',
#       'KG',
#       'LA',
#       'MO',
#       'MN',
#       'NP',
#       'UZ',
#       'IQ',
#       'TJ',
#       'VE',
#       'XK'],
#      'explicit': True,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'CW',
#        'DM',
#        'FJ',
#        'GE',
#        'GD',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'MH',
#        'FM',
#        'NR',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'KH',
#        'KG',
#        'LA',
#        'MO',
#        'MN',
#        'NP',
#        'UZ',
#        'IQ',
#        'TJ',
#        'VE',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/63ezU6APPdP6rnKWJBowPL',
#       'id': '63ezU6APPdP6rnKWJBowPL',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2737d4b2daf042da58509f05d73',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e027d4b2daf042da58509f05d73',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d000048517d4b2daf042da58509f05d73',
#         'width': 64,
#         'height': 64}],
#       'name': 'Dutty Love',
#       'release_date': '2024-11-07',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:63ezU6APPdP6rnKWJBowPL',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wAqlYtTaaHELEgyCh9KjG'},
#         'href': 'https://api.spotify.com/v1/artists/4wAqlYtTaaHELEgyCh9KjG',
#         'id': '4wAqlYtTaaHELEgyCh9KjG',
#         'name': 'FAVE',
#         'type': 'artist',
#         'uri': 'spotify:artist:4wAqlYtTaaHELEgyCh9KjG'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/63ezU6APPdP6rnKWJBowPL'},
#       'total_tracks': 7},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wAqlYtTaaHELEgyCh9KjG'},
#        'href': 'https://api.spotify.com/v1/artists/4wAqlYtTaaHELEgyCh9KjG',
#        'id': '4wAqlYtTaaHELEgyCh9KjG',
#        'name': 'FAVE',
#        'type': 'artist',
#        'uri': 'spotify:artist:4wAqlYtTaaHELEgyCh9KjG'}],
#      'disc_number': 1,
#      'track_number': 2,
#      'duration_ms': 156779,
#      'external_ids': {'isrc': 'USAT22407784'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1NQgrLCxEHfswI4AsO1ENN'},
#      'href': 'https://api.spotify.com/v1/tracks/1NQgrLCxEHfswI4AsO1ENN',
#      'id': '1NQgrLCxEHfswI4AsO1ENN',
#      'name': 'Complicated',
#      'popularity': 48,
#      'uri': 'spotify:track:1NQgrLCxEHfswI4AsO1ENN',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2025-04-18T07:25:07Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#      'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#      'id': 'warner.music.central.europe',
#      'type': 'user',
#      'uri': 'spotify:user:warner.music.central.europe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/2IYQwwgxgOIn7t3iF6ufFD',
#       'id': '2IYQwwgxgOIn7t3iF6ufFD',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27336032cb4acd9df050bc2e197',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e0236032cb4acd9df050bc2e197',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d0000485136032cb4acd9df050bc2e197',
#         'width': 64,
#         'height': 64}],
#       'name': 'APT.',
#       'release_date': '2024-10-18',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:2IYQwwgxgOIn7t3iF6ufFD',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eVa5w3URK5duf6eyVDbu9'},
#         'href': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9',
#         'id': '3eVa5w3URK5duf6eyVDbu9',
#         'name': 'ROSÉ',
#         'type': 'artist',
#         'uri': 'spotify:artist:3eVa5w3URK5duf6eyVDbu9'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#         'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#         'id': '0du5cEVh5yTK9QJze8zA0C',
#         'name': 'Bruno Mars',
#         'type': 'artist',
#         'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eVa5w3URK5duf6eyVDbu9'},
#        'href': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9',
#        'id': '3eVa5w3URK5duf6eyVDbu9',
#        'name': 'ROSÉ',
#        'type': 'artist',
#        'uri': 'spotify:artist:3eVa5w3URK5duf6eyVDbu9'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 169917,
#      'external_ids': {'isrc': 'USAT22409172'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5vNRhkKd0yEAg8suGBpjeY'},
#      'href': 'https://api.spotify.com/v1/tracks/5vNRhkKd0yEAg8suGBpjeY',
#      'id': '5vNRhkKd0yEAg8suGBpjeY',
#      'name': 'APT.',
#      'popularity': 96,
#      'uri': 'spotify:track:5vNRhkKd0yEAg8suGBpjeY',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2025-04-18T07:25:07Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#      'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#      'id': 'warner.music.central.europe',
#      'type': 'user',
#      'uri': 'spotify:user:warner.music.central.europe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/01ODTjQ2Rj6db5ViBTwxMk',
#       'id': '01ODTjQ2Rj6db5ViBTwxMk',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273e88eccfe36d5cf11eaf78664',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e02e88eccfe36d5cf11eaf78664',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d00004851e88eccfe36d5cf11eaf78664',
#         'width': 64,
#         'height': 64}],
#       'name': 'Lonely Boy',
#       'release_date': '2025-01-03',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:01ODTjQ2Rj6db5ViBTwxMk',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2DDqcRRVt2xLxMYHD7FQk1'},
#         'href': 'https://api.spotify.com/v1/artists/2DDqcRRVt2xLxMYHD7FQk1',
#         'id': '2DDqcRRVt2xLxMYHD7FQk1',
#         'name': 'L.zwo',
#         'type': 'artist',
#         'uri': 'spotify:artist:2DDqcRRVt2xLxMYHD7FQk1'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/01ODTjQ2Rj6db5ViBTwxMk'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2DDqcRRVt2xLxMYHD7FQk1'},
#        'href': 'https://api.spotify.com/v1/artists/2DDqcRRVt2xLxMYHD7FQk1',
#        'id': '2DDqcRRVt2xLxMYHD7FQk1',
#        'name': 'L.zwo',
#        'type': 'artist',
#        'uri': 'spotify:artist:2DDqcRRVt2xLxMYHD7FQk1'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 203142,
#      'external_ids': {'isrc': 'QZFYX2575665'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2jCvsX9ChvqUOtRb2PdcUW'},
#      'href': 'https://api.spotify.com/v1/tracks/2jCvsX9ChvqUOtRb2PdcUW',
#      'id': '2jCvsX9ChvqUOtRb2PdcUW',
#      'name': 'Lonely Boy',
#      'popularity': 68,
#      'uri': 'spotify:track:2jCvsX9ChvqUOtRb2PdcUW',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2025-04-18T07:25:07Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#      'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#      'id': 'warner.music.central.europe',
#      'type': 'user',
#      'uri': 'spotify:user:warner.music.central.europe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/7CUOkVn3NrdH1Q6y2hmEQx',
#       'id': '7CUOkVn3NrdH1Q6y2hmEQx',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273c35939b4a4fffb5103786d7c',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e02c35939b4a4fffb5103786d7c',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d00004851c35939b4a4fffb5103786d7c',
#         'width': 64,
#         'height': 64}],
#       'name': 'Prismatic: Pack One',
#       'release_date': '2025-01-31',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:7CUOkVn3NrdH1Q6y2hmEQx',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#         'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#         'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#         'name': 'Tiësto',
#         'type': 'artist',
#         'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7CUOkVn3NrdH1Q6y2hmEQx'},
#       'total_tracks': 3},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#        'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#        'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#        'name': 'Tiësto',
#        'type': 'artist',
#        'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1X2sRzO3K7Uvry9JWbG2iO'},
#        'href': 'https://api.spotify.com/v1/artists/1X2sRzO3K7Uvry9JWbG2iO',
#        'id': '1X2sRzO3K7Uvry9JWbG2iO',
#        'name': 'Oaks',
#        'type': 'artist',
#        'uri': 'spotify:artist:1X2sRzO3K7Uvry9JWbG2iO'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 198750,
#      'external_ids': {'isrc': 'CYA112400023'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1aGXmfXBq4koas7v3277P3'},
#      'href': 'https://api.spotify.com/v1/tracks/1aGXmfXBq4koas7v3277P3',
#      'id': '1aGXmfXBq4koas7v3277P3',
#      'name': 'I Follow Rivers',
#      'popularity': 71,
#      'uri': 'spotify:track:1aGXmfXBq4koas7v3277P3',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2025-04-23T11:14:04Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#      'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#      'id': 'warner.music.central.europe',
#      'type': 'user',
#      'uri': 'spotify:user:warner.music.central.europe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/7BILrDqY2kO1SOhX2MUJVN',
#       'id': '7BILrDqY2kO1SOhX2MUJVN',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273abdc94e5010e18f9ee1ace88',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e02abdc94e5010e18f9ee1ace88',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d00004851abdc94e5010e18f9ee1ace88',
#         'width': 64,
#         'height': 64}],
#       'name': 'Your Body',
#       'release_date': '2025-03-21',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:7BILrDqY2kO1SOhX2MUJVN',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MmHXD2ESooP0XdgrVuKTK'},
#         'href': 'https://api.spotify.com/v1/artists/7MmHXD2ESooP0XdgrVuKTK',
#         'id': '7MmHXD2ESooP0XdgrVuKTK',
#         'name': 'Marten Lou',
#         'type': 'artist',
#         'uri': 'spotify:artist:7MmHXD2ESooP0XdgrVuKTK'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7BILrDqY2kO1SOhX2MUJVN'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MmHXD2ESooP0XdgrVuKTK'},
#        'href': 'https://api.spotify.com/v1/artists/7MmHXD2ESooP0XdgrVuKTK',
#        'id': '7MmHXD2ESooP0XdgrVuKTK',
#        'name': 'Marten Lou',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MmHXD2ESooP0XdgrVuKTK'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 228099,
#      'external_ids': {'isrc': 'DEA622500509'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1NKjc6bRHutPoaVtYclFC3'},
#      'href': 'https://api.spotify.com/v1/tracks/1NKjc6bRHutPoaVtYclFC3',
#      'id': '1NKjc6bRHutPoaVtYclFC3',
#      'name': 'Your Body',
#      'popularity': 69,
#      'uri': 'spotify:track:1NKjc6bRHutPoaVtYclFC3',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2025-04-18T07:25:07Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#      'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#      'id': 'warner.music.central.europe',
#      'type': 'user',
#      'uri': 'spotify:user:warner.music.central.europe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/22v4TOSJFegBKWAWg3BtKv',
#       'id': '22v4TOSJFegBKWAWg3BtKv',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2739fa125f25b8a1341ba360eec',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e029fa125f25b8a1341ba360eec',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d000048519fa125f25b8a1341ba360eec',
#         'width': 64,
#         'height': 64}],
#       'name': 'Mr. Predictable',
#       'release_date': '2025-02-21',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:22v4TOSJFegBKWAWg3BtKv',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rjz63sgMaAUAyBMyCUK5D'},
#         'href': 'https://api.spotify.com/v1/artists/5rjz63sgMaAUAyBMyCUK5D',
#         'id': '5rjz63sgMaAUAyBMyCUK5D',
#         'name': 'Avery Anna',
#         'type': 'artist',
#         'uri': 'spotify:artist:5rjz63sgMaAUAyBMyCUK5D'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/22v4TOSJFegBKWAWg3BtKv'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rjz63sgMaAUAyBMyCUK5D'},
#        'href': 'https://api.spotify.com/v1/artists/5rjz63sgMaAUAyBMyCUK5D',
#        'id': '5rjz63sgMaAUAyBMyCUK5D',
#        'name': 'Avery Anna',
#        'type': 'artist',
#        'uri': 'spotify:artist:5rjz63sgMaAUAyBMyCUK5D'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 201133,
#      'external_ids': {'isrc': 'USWB12500125'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4fpf5WsrRHR38hMgqGbqhG'},
#      'href': 'https://api.spotify.com/v1/tracks/4fpf5WsrRHR38hMgqGbqhG',
#      'id': '4fpf5WsrRHR38hMgqGbqhG',
#      'name': 'Mr. Predictable',
#      'popularity': 70,
#      'uri': 'spotify:track:4fpf5WsrRHR38hMgqGbqhG',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2025-04-18T07:25:07Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#      'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#      'id': 'warner.music.central.europe',
#      'type': 'user',
#      'uri': 'spotify:user:warner.music.central.europe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': True,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
# ...
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2025-04-18T07:25:07Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#      'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#      'id': 'warner.music.central.europe',
#      'type': 'user',
#      'uri': 'spotify:user:warner.music.central.europe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/2RpsmC0H0Ozk7wUmTsbbhD',
#       'id': '2RpsmC0H0Ozk7wUmTsbbhD',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273432db5265fbea448c7b974e6',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e02432db5265fbea448c7b974e6',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d00004851432db5265fbea448c7b974e6',
#         'width': 64,
#         'height': 64}],
#       'name': 'La dadi',
#       'release_date': '2024-05-24',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:2RpsmC0H0Ozk7wUmTsbbhD',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19mMHUyLK5uYyg9D14yJP6'},
#         'href': 'https://api.spotify.com/v1/artists/19mMHUyLK5uYyg9D14yJP6',
#         'id': '19mMHUyLK5uYyg9D14yJP6',
#         'name': 'Enisa',
#         'type': 'artist',
#         'uri': 'spotify:artist:19mMHUyLK5uYyg9D14yJP6'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2RpsmC0H0Ozk7wUmTsbbhD'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19mMHUyLK5uYyg9D14yJP6'},
#        'href': 'https://api.spotify.com/v1/artists/19mMHUyLK5uYyg9D14yJP6',
#        'id': '19mMHUyLK5uYyg9D14yJP6',
#        'name': 'Enisa',
#        'type': 'artist',
#        'uri': 'spotify:artist:19mMHUyLK5uYyg9D14yJP6'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 137349,
#      'external_ids': {'isrc': 'USAT22403317'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5kbHPzyUI8hvNWGP6xBKcV'},
#      'href': 'https://api.spotify.com/v1/tracks/5kbHPzyUI8hvNWGP6xBKcV',
#      'id': '5kbHPzyUI8hvNWGP6xBKcV',
#      'name': 'La dadi',
#      'popularity': 34,
#      'uri': 'spotify:track:5kbHPzyUI8hvNWGP6xBKcV',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2025-04-18T07:25:07Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#      'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#      'id': 'warner.music.central.europe',
#      'type': 'user',
#      'uri': 'spotify:user:warner.music.central.europe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/2zBbEyeVF6mHL4mZDtKxAY',
#       'id': '2zBbEyeVF6mHL4mZDtKxAY',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273ea1ed072a470eb678035259a',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e02ea1ed072a470eb678035259a',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d00004851ea1ed072a470eb678035259a',
#         'width': 64,
#         'height': 64}],
#       'name': 'SHADY (Side Of The Moon)',
#       'release_date': '2024-08-30',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:2zBbEyeVF6mHL4mZDtKxAY',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3iMzbvXlgNUpoFccD60bvr'},
#         'href': 'https://api.spotify.com/v1/artists/3iMzbvXlgNUpoFccD60bvr',
#         'id': '3iMzbvXlgNUpoFccD60bvr',
#         'name': 'Prezioso',
#         'type': 'artist',
#         'uri': 'spotify:artist:3iMzbvXlgNUpoFccD60bvr'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/37awA8DFCAnCCL7aqYbDnD'},
#         'href': 'https://api.spotify.com/v1/artists/37awA8DFCAnCCL7aqYbDnD',
#         'id': '37awA8DFCAnCCL7aqYbDnD',
#         'name': 'Blasterjaxx',
#         'type': 'artist',
#         'uri': 'spotify:artist:37awA8DFCAnCCL7aqYbDnD'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/3DgZk9TPxWee4QgbRpKGF4'},
#         'href': 'https://api.spotify.com/v1/artists/3DgZk9TPxWee4QgbRpKGF4',
#         'id': '3DgZk9TPxWee4QgbRpKGF4',
#         'name': 'Shibui',
#         'type': 'artist',
#         'uri': 'spotify:artist:3DgZk9TPxWee4QgbRpKGF4'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2zBbEyeVF6mHL4mZDtKxAY'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3iMzbvXlgNUpoFccD60bvr'},
#        'href': 'https://api.spotify.com/v1/artists/3iMzbvXlgNUpoFccD60bvr',
#        'id': '3iMzbvXlgNUpoFccD60bvr',
#        'name': 'Prezioso',
#        'type': 'artist',
#        'uri': 'spotify:artist:3iMzbvXlgNUpoFccD60bvr'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/37awA8DFCAnCCL7aqYbDnD'},
#        'href': 'https://api.spotify.com/v1/artists/37awA8DFCAnCCL7aqYbDnD',
#        'id': '37awA8DFCAnCCL7aqYbDnD',
#        'name': 'Blasterjaxx',
#        'type': 'artist',
#        'uri': 'spotify:artist:37awA8DFCAnCCL7aqYbDnD'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3DgZk9TPxWee4QgbRpKGF4'},
#        'href': 'https://api.spotify.com/v1/artists/3DgZk9TPxWee4QgbRpKGF4',
#        'id': '3DgZk9TPxWee4QgbRpKGF4',
#        'name': 'Shibui',
#        'type': 'artist',
#        'uri': 'spotify:artist:3DgZk9TPxWee4QgbRpKGF4'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 143478,
#      'external_ids': {'isrc': 'NLZ542400593'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6gW0R1YE6L8rHB9b0SnCFq'},
#      'href': 'https://api.spotify.com/v1/tracks/6gW0R1YE6L8rHB9b0SnCFq',
#      'id': '6gW0R1YE6L8rHB9b0SnCFq',
#      'name': 'SHADY (Side Of The Moon)',
#      'popularity': 45,
#      'uri': 'spotify:track:6gW0R1YE6L8rHB9b0SnCFq',
#      'is_local': False},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': 'https://api.spotify.com/v1/playlists/3uq1jrrLNf3nbqO9cV4NCK/tracks?offset=100&limit=100&additional_types=track',
#   'offset': 0,
#   'previous': None,
#   'total': 104},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:3uq1jrrLNf3nbqO9cV4NCK'}

# %% [markdown]
# # Getting albums

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %% [markdown]
# Example: Coldplay

# %% [markdown]
# ## Getting the songs of a given album
